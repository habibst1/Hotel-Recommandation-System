# %%
import json
import torch
from transformers import pipeline
from datetime import datetime
from colorama import init, Fore

# Initialize colorama
init(autoreset=True)

def load_classification_model():
    model_name = "./deception_detector_bert_cased"
    print(Fore.YELLOW + f"Loading model from: {model_name}")
    classifier = pipeline(
        "text-classification", 
        model=model_name, 
        tokenizer=model_name,
        device=0 if torch.cuda.is_available() else -1
    )
    print(Fore.GREEN + f"Model loaded on {'GPU' if torch.cuda.is_available() else 'CPU'}")
    return classifier

def combine_hotel_data(details_file, reviews_file, output_file, classifier):
    print(Fore.YELLOW + f"\nLoading hotel details from: {details_file}")
    with open(details_file, 'r', encoding='utf-8') as f:
        hotel_details = json.load(f)
    
    print(Fore.YELLOW + f"Loading hotel reviews from: {reviews_file}")
    with open(reviews_file, 'r', encoding='utf-8') as f:
        hotel_reviews = json.load(f)
    
    reviews_dict = {hotel['hotel_number']: hotel['reviews'] for hotel in hotel_reviews}
    print(Fore.CYAN + f"\nFound {len(hotel_details)} hotels in details and {len(hotel_reviews)} hotels in reviews")
    
    combined_hotels = []
    total_reviews = 0
    kept_reviews = 0
    
    for hotel in hotel_details:
        hotel_number = hotel['hotel_number']
        hotel_name = hotel['name']
        print(Fore.MAGENTA + f"\nProcessing hotel #{hotel_number}: {hotel_name}")
        
        if hotel_number in reviews_dict:
            combined_hotel = hotel.copy()
            hotel_reviews_list = reviews_dict[hotel_number]
            print(Fore.CYAN + f"  Found {len(hotel_reviews_list)} reviews")
            
            truthful_reviews = []
            
            for review in hotel_reviews_list:
                total_reviews += 1
                review_text = review['review_text']
                
                # Print progress without spamming too much
                if total_reviews % 5 == 0:
                    print(Fore.WHITE + f"  Processing review {total_reviews}...", end='\r')
                
                try:
                    result = classifier(review_text)[0]
                    label = result['label']
                    score = result['score']
                    
                    if label.lower() == "truthful":
                        truthful_reviews.append(review)
                        kept_reviews += 1
                        print(Fore.GREEN + f"  ✓ Kept review (classified as {label} with  {score:.2%} confidence)")
                    else:
                        print(Fore.RED + f"  ✗ Filtered out (classified as {label} with {score:.2%} confidence)")
                        
                except Exception as e:
                    print(Fore.YELLOW + f"  ! Error processing review: {str(e)} - remove it to be safe")

            
            if truthful_reviews:
                combined_hotel['reviews'] = truthful_reviews
                combined_hotels.append(combined_hotel)
                print(Fore.GREEN + f"  Kept {len(truthful_reviews)}/{len(hotel_reviews_list)} reviews")
            else:
                print(Fore.YELLOW + "  No reviews kept for this hotel")
        else:
            print(Fore.YELLOW + "  No reviews found for this hotel")
    
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(combined_hotels, f, ensure_ascii=False, indent=2)
    
    print(Fore.CYAN + "\nSUMMARY:")
    print(Fore.WHITE + f"Total reviews processed: {total_reviews}")
    print(Fore.GREEN + f"Reviews kept (truthful): {kept_reviews} ({kept_reviews/total_reviews:.1%})")
    print(Fore.RED + f"Reviews filtered out: {total_reviews - kept_reviews} ({(total_reviews - kept_reviews)/total_reviews:.1%})")
    print(Fore.MAGENTA + f"Results saved to: {output_file}")

if __name__ == "__main__":
    try:
        classifier = load_classification_model()
        combine_hotel_data(
            'hotels_details_no_reviews.json',
            'hotels_reviews_only.json',
            'hotels_details_reviews_filtered.json',
            classifier
        )
    except Exception as e:
        print(Fore.RED + f"\nERROR: {str(e)}")
        raise
# Out:
# Loading model from: ./deception_detector_bert_cased
# WARNING:tensorflow:From C:\Users\Mega-PC\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Device set to use cpu
# Model loaded on CPU
#
# Loading hotel details from: hotels_details_no_reviews.json
# Loading hotel reviews from: hotels_reviews_only.json
#
# Found 169 hotels in details and 169 hotels in reviews
#
# Processing hotel #1: The Residence Tunis
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  64.79% confidence)
#   ✓ Kept review (classified as truthful with  90.71% confidence)
#   ✓ Kept review (classified as truthful with  92.27% confidence)
#   ✗ Filtered out (classified as deceptive with 62.51% confidence)
#   ✓ Kept review (classified as truthful with  91.09% confidence)
#   ✓ Kept review (classified as truthful with  64.75% confidence)
#   ✓ Kept review (classified as truthful with  91.74% confidence)
#   ✓ Kept review (classified as truthful with  79.84% confidence)
#   ✗ Filtered out (classified as deceptive with 86.60% confidence)
#   ✗ Filtered out (classified as deceptive with 89.67% confidence)
#   ✓ Kept review (classified as truthful with  89.00% confidence)
#   ✓ Kept review (classified as truthful with  92.01% confidence)
#   ✓ Kept review (classified as truthful with  91.54% confidence)
#   ✗ Filtered out (classified as deceptive with 77.26% confidence)
#   ✓ Kept review (classified as truthful with  91.29% confidence)
#   ✓ Kept review (classified as truthful with  81.82% confidence)
#   ✓ Kept review (classified as truthful with  93.33% confidence)
#   ✓ Kept review (classified as truthful with  89.36% confidence)
#   ✓ Kept review (classified as truthful with  64.07% confidence)
#   ✓ Kept review (classified as truthful with  85.63% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #2: Iberostar Waves Mehari Djerba
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  65.56% confidence)
#   ✗ Filtered out (classified as deceptive with 71.77% confidence)
#   ✗ Filtered out (classified as deceptive with 50.54% confidence)
#   ✓ Kept review (classified as truthful with  78.28% confidence)
#   ✓ Kept review (classified as truthful with  77.66% confidence)
#   ✓ Kept review (classified as truthful with  91.67% confidence)
#   ✓ Kept review (classified as truthful with  91.57% confidence)
#   ✓ Kept review (classified as truthful with  89.87% confidence)
#   ✓ Kept review (classified as truthful with  91.09% confidence)
#   ✓ Kept review (classified as truthful with  89.02% confidence)
#   ✓ Kept review (classified as truthful with  90.82% confidence)
#   ✓ Kept review (classified as truthful with  83.04% confidence)
#   ✓ Kept review (classified as truthful with  92.63% confidence)
#   ✓ Kept review (classified as truthful with  91.88% confidence)
#   ✓ Kept review (classified as truthful with  90.58% confidence)
#   ✓ Kept review (classified as truthful with  91.41% confidence)
#   ✓ Kept review (classified as truthful with  89.56% confidence)
#   ✗ Filtered out (classified as deceptive with 64.68% confidence)
#   ✓ Kept review (classified as truthful with  91.12% confidence)
#   ✓ Kept review (classified as truthful with  91.95% confidence)
#   Kept 17/20 reviews
#
# Processing hotel #3: Movenpick Resort & Marine Spa Sousse
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  55.04% confidence)
#   ✗ Filtered out (classified as deceptive with 84.39% confidence)
#   ✓ Kept review (classified as truthful with  93.33% confidence)
#   ✗ Filtered out (classified as deceptive with 57.98% confidence)
#   ✓ Kept review (classified as truthful with  92.83% confidence)
#   ✓ Kept review (classified as truthful with  76.89% confidence)
#   ✓ Kept review (classified as truthful with  87.67% confidence)
#   ✓ Kept review (classified as truthful with  89.58% confidence)
#   ✓ Kept review (classified as truthful with  89.17% confidence)
#   ✗ Filtered out (classified as deceptive with 75.82% confidence)
#   ✓ Kept review (classified as truthful with  88.14% confidence)
#   ✓ Kept review (classified as truthful with  91.51% confidence)
#   ✓ Kept review (classified as truthful with  88.85% confidence)
#   ✓ Kept review (classified as truthful with  92.77% confidence)
#   ✓ Kept review (classified as truthful with  54.04% confidence)
#   ✓ Kept review (classified as truthful with  79.22% confidence)
#   ✓ Kept review (classified as truthful with  83.98% confidence)
#   ✓ Kept review (classified as truthful with  92.35% confidence)
#   ✓ Kept review (classified as truthful with  89.91% confidence)
#   ✓ Kept review (classified as truthful with  77.90% confidence)
#   Kept 17/20 reviews
#
# Processing hotel #4: Telemaque Beach & Spa
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  93.26% confidence)
#   ✓ Kept review (classified as truthful with  92.55% confidence)
#   ✓ Kept review (classified as truthful with  92.65% confidence)
#   ✓ Kept review (classified as truthful with  90.82% confidence)
#   ✓ Kept review (classified as truthful with  81.65% confidence)
#   ✓ Kept review (classified as truthful with  66.28% confidence)
#   ✓ Kept review (classified as truthful with  58.56% confidence)
#   ✓ Kept review (classified as truthful with  87.26% confidence)
#   ✓ Kept review (classified as truthful with  87.99% confidence)
#   ✓ Kept review (classified as truthful with  91.01% confidence)
#   ✓ Kept review (classified as truthful with  80.86% confidence)
#   ✓ Kept review (classified as truthful with  84.02% confidence)
#   ✓ Kept review (classified as truthful with  83.75% confidence)
#   ✓ Kept review (classified as truthful with  81.79% confidence)
#   ✓ Kept review (classified as truthful with  90.16% confidence)
#   ✓ Kept review (classified as truthful with  91.32% confidence)
#   ✓ Kept review (classified as truthful with  92.20% confidence)
#   ✓ Kept review (classified as truthful with  91.45% confidence)
#   ✓ Kept review (classified as truthful with  86.10% confidence)
#   ✓ Kept review (classified as truthful with  86.33% confidence)
#   Kept 20/20 reviews
#
# Processing hotel #5: Medina Belisaire & Thalasso
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  93.17% confidence)
#   ✗ Filtered out (classified as deceptive with 59.64% confidence)
#   ✓ Kept review (classified as truthful with  78.02% confidence)
#   ✓ Kept review (classified as truthful with  80.88% confidence)
#   Processing review 85...
# Token indices sequence length is longer than the specified maximum sequence length for this model (1140 > 512). Running this sequence through the model will result in indexing errors
#   ! Error processing review: The size of tensor a (1140) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  92.83% confidence)
#   ✓ Kept review (classified as truthful with  87.66% confidence)
#   ! Error processing review: The size of tensor a (581) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  93.35% confidence)
#   ✓ Kept review (classified as truthful with  64.66% confidence)
#   ✓ Kept review (classified as truthful with  93.77% confidence)
#   ✓ Kept review (classified as truthful with  91.63% confidence)
#   ✓ Kept review (classified as truthful with  89.73% confidence)
#   ✓ Kept review (classified as truthful with  86.01% confidence)
#   ✓ Kept review (classified as truthful with  91.12% confidence)
#   ✓ Kept review (classified as truthful with  84.07% confidence)
#   ! Error processing review: The size of tensor a (523) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  89.07% confidence)
#   ✓ Kept review (classified as truthful with  89.71% confidence)
#   ✓ Kept review (classified as truthful with  90.01% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #6: Steigenberger Marhaba Thalasso
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  93.08% confidence)
#   ✓ Kept review (classified as truthful with  80.60% confidence)
#   ✓ Kept review (classified as truthful with  87.88% confidence)
#   ✓ Kept review (classified as truthful with  93.69% confidence)
#   ✓ Kept review (classified as truthful with  89.55% confidence)
#   ✗ Filtered out (classified as deceptive with 74.81% confidence)
#   ✓ Kept review (classified as truthful with  91.70% confidence)
#   ✓ Kept review (classified as truthful with  80.67% confidence)
#   ✓ Kept review (classified as truthful with  81.22% confidence)
#   ✓ Kept review (classified as truthful with  87.81% confidence)
#   ✓ Kept review (classified as truthful with  89.74% confidence)
#   ✓ Kept review (classified as truthful with  93.16% confidence)
#   ✓ Kept review (classified as truthful with  91.00% confidence)
#   ✓ Kept review (classified as truthful with  89.18% confidence)
#   ✓ Kept review (classified as truthful with  88.94% confidence)
#   ✗ Filtered out (classified as deceptive with 79.78% confidence)
#   ✓ Kept review (classified as truthful with  90.32% confidence)
#   ✓ Kept review (classified as truthful with  90.99% confidence)
#   ✓ Kept review (classified as truthful with  80.71% confidence)
#   ✓ Kept review (classified as truthful with  59.53% confidence)
#   Kept 18/20 reviews
#
# Processing hotel #7: JAZ Tour Khalef Hotel
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  88.94% confidence)
#   ✓ Kept review (classified as truthful with  61.95% confidence)
#   ✗ Filtered out (classified as deceptive with 78.80% confidence)
#   ✓ Kept review (classified as truthful with  83.69% confidence)
#   ✓ Kept review (classified as truthful with  75.52% confidence)
#   ✓ Kept review (classified as truthful with  89.90% confidence)
#   ! Error processing review: The size of tensor a (598) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  88.80% confidence)
#   ✓ Kept review (classified as truthful with  90.38% confidence)
#   ✓ Kept review (classified as truthful with  71.67% confidence)
#   ✓ Kept review (classified as truthful with  50.96% confidence)
#   ✓ Kept review (classified as truthful with  92.99% confidence)
#   ✓ Kept review (classified as truthful with  60.30% confidence)
#   ✓ Kept review (classified as truthful with  91.40% confidence)
#   ✓ Kept review (classified as truthful with  93.71% confidence)
#   ✓ Kept review (classified as truthful with  92.91% confidence)
#   ✓ Kept review (classified as truthful with  92.66% confidence)
#   ✗ Filtered out (classified as deceptive with 70.74% confidence)
#   ✓ Kept review (classified as truthful with  91.07% confidence)
#   ✓ Kept review (classified as truthful with  90.06% confidence)
#   Kept 17/20 reviews
#
# Processing hotel #8: Iberostar Selection Royal El Mansour
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  65.18% confidence)
#   ✗ Filtered out (classified as deceptive with 71.77% confidence)
#   ✓ Kept review (classified as truthful with  92.63% confidence)
#   ✓ Kept review (classified as truthful with  80.74% confidence)
#   ! Error processing review: The size of tensor a (1322) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  84.95% confidence)
#   ✗ Filtered out (classified as deceptive with 75.50% confidence)
#   ✓ Kept review (classified as truthful with  88.83% confidence)
#   ✓ Kept review (classified as truthful with  80.94% confidence)
#   ! Error processing review: The size of tensor a (659) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ! Error processing review: The size of tensor a (2682) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  88.82% confidence)
#   ✓ Kept review (classified as truthful with  90.46% confidence)
#   ✓ Kept review (classified as truthful with  60.87% confidence)
#   ✓ Kept review (classified as truthful with  71.01% confidence)
#   ✗ Filtered out (classified as deceptive with 64.46% confidence)
#   ✓ Kept review (classified as truthful with  78.83% confidence)
#   ✓ Kept review (classified as truthful with  90.52% confidence)
#   ✓ Kept review (classified as truthful with  89.33% confidence)
#   ✓ Kept review (classified as truthful with  84.66% confidence)
#   Kept 14/20 reviews
#
# Processing hotel #9: Iberostar Waves Averroes
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  69.25% confidence)
#   ✓ Kept review (classified as truthful with  84.37% confidence)
#   ✓ Kept review (classified as truthful with  90.33% confidence)
#   ! Error processing review: The size of tensor a (2094) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  93.57% confidence)
#   ✓ Kept review (classified as truthful with  92.32% confidence)
#   ✓ Kept review (classified as truthful with  84.32% confidence)
#   ! Error processing review: The size of tensor a (617) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  89.87% confidence)
#   ✓ Kept review (classified as truthful with  52.24% confidence)
#   ✓ Kept review (classified as truthful with  84.31% confidence)
#   ✓ Kept review (classified as truthful with  79.72% confidence)
#   ! Error processing review: The size of tensor a (513) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  53.81% confidence)
#   ✓ Kept review (classified as truthful with  93.11% confidence)
#   ✓ Kept review (classified as truthful with  86.54% confidence)
#   ! Error processing review: The size of tensor a (942) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  88.57% confidence)
#   ✓ Kept review (classified as truthful with  87.69% confidence)
#   ✓ Kept review (classified as truthful with  90.61% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #10: El Mouradi Palm Marina
#   Found 20 reviews
#   ✗ Filtered out (classified as deceptive with 64.29% confidence)
#   ✓ Kept review (classified as truthful with  92.14% confidence)
#   ✗ Filtered out (classified as deceptive with 79.87% confidence)
#   ✓ Kept review (classified as truthful with  57.49% confidence)
#   ✓ Kept review (classified as truthful with  84.28% confidence)
#   ✓ Kept review (classified as truthful with  76.77% confidence)
#   ✓ Kept review (classified as truthful with  92.33% confidence)
#   ✗ Filtered out (classified as deceptive with 76.61% confidence)
#   ✓ Kept review (classified as truthful with  91.82% confidence)
#   ! Error processing review: The size of tensor a (974) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 56.23% confidence)
#   ✗ Filtered out (classified as deceptive with 70.80% confidence)
#   ✓ Kept review (classified as truthful with  87.39% confidence)
#   ✓ Kept review (classified as truthful with  58.68% confidence)
#   ! Error processing review: The size of tensor a (1185) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 79.25% confidence)
#   ✓ Kept review (classified as truthful with  68.98% confidence)
#   ✓ Kept review (classified as truthful with  86.96% confidence)
#   ✓ Kept review (classified as truthful with  90.64% confidence)
#   ✓ Kept review (classified as truthful with  85.25% confidence)
#   Kept 12/20 reviews
#
# Processing hotel #11: Iberostar Selection Kantaoui Bay
#   Found 20 reviews
#   ✗ Filtered out (classified as deceptive with 64.29% confidence)
#   ✓ Kept review (classified as truthful with  92.14% confidence)
#   ✗ Filtered out (classified as deceptive with 79.87% confidence)
#   ✓ Kept review (classified as truthful with  57.49% confidence)
#   ✓ Kept review (classified as truthful with  84.28% confidence)
#   ✓ Kept review (classified as truthful with  76.77% confidence)
#   ✓ Kept review (classified as truthful with  92.33% confidence)
#   ✗ Filtered out (classified as deceptive with 76.61% confidence)
#   ✓ Kept review (classified as truthful with  91.82% confidence)
#   ! Error processing review: The size of tensor a (974) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 56.23% confidence)
#   ✗ Filtered out (classified as deceptive with 70.80% confidence)
#   ✓ Kept review (classified as truthful with  87.39% confidence)
#   ✓ Kept review (classified as truthful with  58.68% confidence)
#   ! Error processing review: The size of tensor a (1185) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 79.25% confidence)
#   ✓ Kept review (classified as truthful with  68.98% confidence)
#   ✓ Kept review (classified as truthful with  86.96% confidence)
#   ✓ Kept review (classified as truthful with  90.64% confidence)
#   ✓ Kept review (classified as truthful with  85.25% confidence)
#   Kept 12/20 reviews
#
# Processing hotel #12: Lella Baya & Thalasso Hotel
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  89.98% confidence)
#   ✓ Kept review (classified as truthful with  68.02% confidence)
#   ✓ Kept review (classified as truthful with  91.91% confidence)
#   ✓ Kept review (classified as truthful with  93.20% confidence)
#   ✓ Kept review (classified as truthful with  91.48% confidence)
#   ✓ Kept review (classified as truthful with  88.63% confidence)
#   ✓ Kept review (classified as truthful with  85.66% confidence)
#   ✓ Kept review (classified as truthful with  55.34% confidence)
#   ✓ Kept review (classified as truthful with  92.88% confidence)
#   ✓ Kept review (classified as truthful with  88.62% confidence)
#   ✓ Kept review (classified as truthful with  90.77% confidence)
#   ✓ Kept review (classified as truthful with  85.40% confidence)
#   ✓ Kept review (classified as truthful with  92.06% confidence)
#   ✓ Kept review (classified as truthful with  77.88% confidence)
#   ✓ Kept review (classified as truthful with  93.39% confidence)
#   ✗ Filtered out (classified as deceptive with 62.80% confidence)
#   ✗ Filtered out (classified as deceptive with 52.75% confidence)
#   ✓ Kept review (classified as truthful with  90.13% confidence)
#   ✓ Kept review (classified as truthful with  83.38% confidence)
#   ✓ Kept review (classified as truthful with  72.32% confidence)
#   Kept 18/20 reviews
#
# Processing hotel #13: Hotel Bel Azur Thalasso & Bungalows
#   Found 20 reviews
#   ! Error processing review: The size of tensor a (541) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 90.19% confidence)
#   ✗ Filtered out (classified as deceptive with 87.90% confidence)
#   ✗ Filtered out (classified as deceptive with 83.07% confidence)
#   ✓ Kept review (classified as truthful with  53.11% confidence)
#   ✓ Kept review (classified as truthful with  86.45% confidence)
#   ✗ Filtered out (classified as deceptive with 65.68% confidence)
#   ✓ Kept review (classified as truthful with  55.65% confidence)
#   ✓ Kept review (classified as truthful with  92.03% confidence)
#   ✓ Kept review (classified as truthful with  62.94% confidence)
#   ✗ Filtered out (classified as deceptive with 77.61% confidence)
#   ✓ Kept review (classified as truthful with  56.42% confidence)
#   ✓ Kept review (classified as truthful with  61.72% confidence)
#   ✓ Kept review (classified as truthful with  84.15% confidence)
#   ✗ Filtered out (classified as deceptive with 67.85% confidence)
#   ✓ Kept review (classified as truthful with  92.50% confidence)
#   ✓ Kept review (classified as truthful with  84.83% confidence)
#   ✓ Kept review (classified as truthful with  93.40% confidence)
#   ✗ Filtered out (classified as deceptive with 62.46% confidence)
#   ✓ Kept review (classified as truthful with  92.09% confidence)
#   Kept 12/20 reviews
#
# Processing hotel #14: Iberostar Selection Diar El Andalous
#   Found 20 reviews
#   ✗ Filtered out (classified as deceptive with 81.33% confidence)
#   ✓ Kept review (classified as truthful with  93.46% confidence)
#   ✓ Kept review (classified as truthful with  50.84% confidence)
#   ✓ Kept review (classified as truthful with  93.42% confidence)
#   ✓ Kept review (classified as truthful with  59.93% confidence)
#   ✓ Kept review (classified as truthful with  91.34% confidence)
#   ✓ Kept review (classified as truthful with  92.30% confidence)
#   ✓ Kept review (classified as truthful with  63.06% confidence)
#   ✓ Kept review (classified as truthful with  89.52% confidence)
#   ✓ Kept review (classified as truthful with  90.45% confidence)
#   ✓ Kept review (classified as truthful with  71.56% confidence)
#   ✗ Filtered out (classified as deceptive with 70.03% confidence)
#   ✓ Kept review (classified as truthful with  83.61% confidence)
#   ✓ Kept review (classified as truthful with  77.47% confidence)
#   ✓ Kept review (classified as truthful with  82.87% confidence)
#   ✓ Kept review (classified as truthful with  92.36% confidence)
#   ✓ Kept review (classified as truthful with  89.23% confidence)
#   ✓ Kept review (classified as truthful with  72.28% confidence)
#   ✓ Kept review (classified as truthful with  73.77% confidence)
#   ✓ Kept review (classified as truthful with  81.47% confidence)
#   Kept 18/20 reviews
#
# Processing hotel #15: Riadh Palms Resort & Spa
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  87.29% confidence)
#   ✓ Kept review (classified as truthful with  89.06% confidence)
#   ✓ Kept review (classified as truthful with  91.66% confidence)
#   ✓ Kept review (classified as truthful with  87.18% confidence)
#   ✓ Kept review (classified as truthful with  67.62% confidence)
#   ✓ Kept review (classified as truthful with  88.14% confidence)
#   ✓ Kept review (classified as truthful with  91.05% confidence)
#   ✓ Kept review (classified as truthful with  85.59% confidence)
#   ✓ Kept review (classified as truthful with  90.99% confidence)
#   ✓ Kept review (classified as truthful with  74.09% confidence)
#   ✓ Kept review (classified as truthful with  74.09% confidence)
#   ✓ Kept review (classified as truthful with  88.27% confidence)
#   ✓ Kept review (classified as truthful with  75.39% confidence)
#   ✓ Kept review (classified as truthful with  81.33% confidence)
#   ✓ Kept review (classified as truthful with  65.97% confidence)
#   ! Error processing review: The size of tensor a (857) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  84.18% confidence)
#   ✓ Kept review (classified as truthful with  85.81% confidence)
#   ✓ Kept review (classified as truthful with  84.10% confidence)
#   ✓ Kept review (classified as truthful with  67.84% confidence)
#   Kept 19/20 reviews
#
# Processing hotel #16: Radisson Blu Palace Resort & Thalasso, Djerba
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  91.08% confidence)
#   ✓ Kept review (classified as truthful with  87.93% confidence)
#   ✓ Kept review (classified as truthful with  91.42% confidence)
#   ✓ Kept review (classified as truthful with  91.19% confidence)
#   ✓ Kept review (classified as truthful with  90.89% confidence)
#   ✓ Kept review (classified as truthful with  92.34% confidence)
#   ✓ Kept review (classified as truthful with  81.37% confidence)
#   ! Error processing review: The size of tensor a (533) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  92.03% confidence)
#   ✓ Kept review (classified as truthful with  92.76% confidence)
#   ✓ Kept review (classified as truthful with  52.40% confidence)
#   ✓ Kept review (classified as truthful with  91.53% confidence)
#   ✓ Kept review (classified as truthful with  85.72% confidence)
#   ✓ Kept review (classified as truthful with  76.72% confidence)
#   ✓ Kept review (classified as truthful with  86.00% confidence)
#   ✓ Kept review (classified as truthful with  91.23% confidence)
#   ✓ Kept review (classified as truthful with  91.36% confidence)
#   ✗ Filtered out (classified as deceptive with 74.36% confidence)
#   ✓ Kept review (classified as truthful with  50.69% confidence)
#   ✓ Kept review (classified as truthful with  92.13% confidence)
#   Kept 18/20 reviews
#
# Processing hotel #17: Hotel Sol Azur Beach & CongrÃ¨s
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  89.52% confidence)
#   ✓ Kept review (classified as truthful with  88.48% confidence)
#   ✓ Kept review (classified as truthful with  89.79% confidence)
#   ✓ Kept review (classified as truthful with  90.05% confidence)
#   ✓ Kept review (classified as truthful with  93.53% confidence)
#   ✗ Filtered out (classified as deceptive with 73.55% confidence)
#   ✓ Kept review (classified as truthful with  75.59% confidence)
#   ✓ Kept review (classified as truthful with  70.83% confidence)
#   ✓ Kept review (classified as truthful with  80.51% confidence)
#   ✗ Filtered out (classified as deceptive with 78.25% confidence)
#   ✓ Kept review (classified as truthful with  79.96% confidence)
#   ✓ Kept review (classified as truthful with  57.28% confidence)
#   ✓ Kept review (classified as truthful with  91.36% confidence)
#   ✓ Kept review (classified as truthful with  89.99% confidence)
#   ✗ Filtered out (classified as deceptive with 64.49% confidence)
#   ✓ Kept review (classified as truthful with  90.45% confidence)
#   ✓ Kept review (classified as truthful with  89.31% confidence)
#   ✓ Kept review (classified as truthful with  87.98% confidence)
#   ✓ Kept review (classified as truthful with  92.33% confidence)
#   ✗ Filtered out (classified as deceptive with 90.07% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #18: Djerba Aqua Resort
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  92.96% confidence)
#   ✓ Kept review (classified as truthful with  71.77% confidence)
#   ✓ Kept review (classified as truthful with  82.41% confidence)
#   ✓ Kept review (classified as truthful with  92.40% confidence)
#   ✓ Kept review (classified as truthful with  91.99% confidence)
#   ✓ Kept review (classified as truthful with  91.16% confidence)
#   ✓ Kept review (classified as truthful with  80.83% confidence)
#   ✓ Kept review (classified as truthful with  87.01% confidence)
#   ✓ Kept review (classified as truthful with  86.62% confidence)
#   ✓ Kept review (classified as truthful with  63.68% confidence)
#   ✓ Kept review (classified as truthful with  56.98% confidence)
#   ! Error processing review: The size of tensor a (736) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  54.48% confidence)
#   ✓ Kept review (classified as truthful with  88.37% confidence)
#   ✓ Kept review (classified as truthful with  89.75% confidence)
#   ✓ Kept review (classified as truthful with  53.53% confidence)
#   ✓ Kept review (classified as truthful with  85.50% confidence)
#   ✓ Kept review (classified as truthful with  81.19% confidence)
#   ✓ Kept review (classified as truthful with  74.70% confidence)
#   ✓ Kept review (classified as truthful with  80.96% confidence)
#   Kept 19/20 reviews
#
# Processing hotel #19: Hotel Le Sultan
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  89.33% confidence)
#   ✗ Filtered out (classified as deceptive with 51.34% confidence)
#   ✗ Filtered out (classified as deceptive with 87.22% confidence)
#   ✓ Kept review (classified as truthful with  91.71% confidence)
#   ✓ Kept review (classified as truthful with  93.00% confidence)
#   ✓ Kept review (classified as truthful with  93.23% confidence)
#   ✓ Kept review (classified as truthful with  78.51% confidence)
#   ✓ Kept review (classified as truthful with  92.34% confidence)
#   ✓ Kept review (classified as truthful with  54.98% confidence)
#   ✓ Kept review (classified as truthful with  84.74% confidence)
#   ✗ Filtered out (classified as deceptive with 89.84% confidence)
#   ✓ Kept review (classified as truthful with  61.83% confidence)
#   ✓ Kept review (classified as truthful with  62.02% confidence)
#   ✗ Filtered out (classified as deceptive with 87.94% confidence)
#   ✗ Filtered out (classified as deceptive with 80.64% confidence)
#   ✓ Kept review (classified as truthful with  90.41% confidence)
#   ✗ Filtered out (classified as deceptive with 59.72% confidence)
#   ✓ Kept review (classified as truthful with  89.05% confidence)
#   ✓ Kept review (classified as truthful with  84.52% confidence)
#   ✓ Kept review (classified as truthful with  86.60% confidence)
#   Kept 14/20 reviews
#
# Processing hotel #20: La Badira
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  92.09% confidence)
#   ! Error processing review: The size of tensor a (616) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  83.23% confidence)
#   ✗ Filtered out (classified as deceptive with 88.13% confidence)
#   ✓ Kept review (classified as truthful with  90.42% confidence)
#   ✗ Filtered out (classified as deceptive with 87.38% confidence)
#   ✓ Kept review (classified as truthful with  93.03% confidence)
#   ✓ Kept review (classified as truthful with  87.04% confidence)
#   ✗ Filtered out (classified as deceptive with 88.74% confidence)
#   ✗ Filtered out (classified as deceptive with 73.18% confidence)
#   ✓ Kept review (classified as truthful with  87.28% confidence)
#   ✓ Kept review (classified as truthful with  71.25% confidence)
#   ✓ Kept review (classified as truthful with  91.40% confidence)
#   ✓ Kept review (classified as truthful with  90.32% confidence)
#   ✗ Filtered out (classified as deceptive with 85.58% confidence)
#   ✓ Kept review (classified as truthful with  86.37% confidence)
#   ✓ Kept review (classified as truthful with  91.82% confidence)
#   ✗ Filtered out (classified as deceptive with 61.18% confidence)
#   ✓ Kept review (classified as truthful with  89.88% confidence)
#   ✓ Kept review (classified as truthful with  64.96% confidence)
#   Kept 13/20 reviews
#
# Processing hotel #21: Marhaba Club
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  93.49% confidence)
#   ✓ Kept review (classified as truthful with  88.55% confidence)
#   ✓ Kept review (classified as truthful with  93.04% confidence)
#   ✗ Filtered out (classified as deceptive with 56.79% confidence)
#   ✓ Kept review (classified as truthful with  91.72% confidence)
#   ✓ Kept review (classified as truthful with  91.38% confidence)
#   ✓ Kept review (classified as truthful with  90.63% confidence)
#   ✓ Kept review (classified as truthful with  66.76% confidence)
#   ✓ Kept review (classified as truthful with  90.45% confidence)
#   ✓ Kept review (classified as truthful with  70.62% confidence)
#   ✓ Kept review (classified as truthful with  84.61% confidence)
#   ✓ Kept review (classified as truthful with  93.48% confidence)
#   ✓ Kept review (classified as truthful with  93.18% confidence)
#   ✗ Filtered out (classified as deceptive with 66.02% confidence)
#   ✗ Filtered out (classified as deceptive with 69.84% confidence)
#   ✓ Kept review (classified as truthful with  90.01% confidence)
#   ✓ Kept review (classified as truthful with  88.43% confidence)
#   ✓ Kept review (classified as truthful with  83.32% confidence)
#   ✓ Kept review (classified as truthful with  91.30% confidence)
#   ✓ Kept review (classified as truthful with  86.40% confidence)
#   Kept 17/20 reviews
#
# Processing hotel #22: Tui Blue Manar
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  82.64% confidence)
#   ✓ Kept review (classified as truthful with  86.90% confidence)
#   ✓ Kept review (classified as truthful with  86.07% confidence)
#   ✗ Filtered out (classified as deceptive with 80.24% confidence)
#   ✓ Kept review (classified as truthful with  54.34% confidence)
#   ✗ Filtered out (classified as deceptive with 67.04% confidence)
#   ✗ Filtered out (classified as deceptive with 59.52% confidence)
#   ✗ Filtered out (classified as deceptive with 88.61% confidence)
#   ✗ Filtered out (classified as deceptive with 83.67% confidence)
#   ✗ Filtered out (classified as deceptive with 71.61% confidence)
#   ✓ Kept review (classified as truthful with  85.02% confidence)
#   ✓ Kept review (classified as truthful with  78.85% confidence)
#   ✓ Kept review (classified as truthful with  91.80% confidence)
#   ✓ Kept review (classified as truthful with  91.67% confidence)
#   ✓ Kept review (classified as truthful with  61.24% confidence)
#   ✓ Kept review (classified as truthful with  91.33% confidence)
#   ✓ Kept review (classified as truthful with  92.72% confidence)
#   ✓ Kept review (classified as truthful with  89.36% confidence)
#   ✓ Kept review (classified as truthful with  83.13% confidence)
#   ✗ Filtered out (classified as deceptive with 81.34% confidence)
#   Kept 13/20 reviews
#
# Processing hotel #23: El Mouradi Palace
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  89.51% confidence)
#   ! Error processing review: The size of tensor a (627) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ! Error processing review: The size of tensor a (756) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 67.35% confidence)
#   ✓ Kept review (classified as truthful with  90.60% confidence)
#   ✓ Kept review (classified as truthful with  90.63% confidence)
#   ✓ Kept review (classified as truthful with  89.21% confidence)
#   ! Error processing review: The size of tensor a (525) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ! Error processing review: The size of tensor a (597) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  92.62% confidence)
#   ✗ Filtered out (classified as deceptive with 54.32% confidence)
#   ✓ Kept review (classified as truthful with  89.24% confidence)
#   ✓ Kept review (classified as truthful with  86.09% confidence)
#   ✓ Kept review (classified as truthful with  91.88% confidence)
#   ✓ Kept review (classified as truthful with  87.16% confidence)
#   ✓ Kept review (classified as truthful with  86.53% confidence)
#   ✓ Kept review (classified as truthful with  90.61% confidence)
#   ✓ Kept review (classified as truthful with  91.59% confidence)
#   ✓ Kept review (classified as truthful with  86.35% confidence)
#   ✓ Kept review (classified as truthful with  87.41% confidence)
#   Kept 14/20 reviews
#
# Processing hotel #24: Dar El Jeld Hotel & Spa
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  59.48% confidence)
#   ✓ Kept review (classified as truthful with  89.68% confidence)
#   ✓ Kept review (classified as truthful with  86.51% confidence)
#   ✓ Kept review (classified as truthful with  87.51% confidence)
#   ✓ Kept review (classified as truthful with  92.38% confidence)
#   ✓ Kept review (classified as truthful with  88.70% confidence)
#   ✓ Kept review (classified as truthful with  89.19% confidence)
#   ✓ Kept review (classified as truthful with  86.16% confidence)
#   ✓ Kept review (classified as truthful with  82.77% confidence)
#   ✓ Kept review (classified as truthful with  89.44% confidence)
#   ✓ Kept review (classified as truthful with  55.53% confidence)
#   ✓ Kept review (classified as truthful with  92.99% confidence)
#   ✓ Kept review (classified as truthful with  91.45% confidence)
#   ✓ Kept review (classified as truthful with  54.56% confidence)
#   ✓ Kept review (classified as truthful with  91.31% confidence)
#   ✓ Kept review (classified as truthful with  61.91% confidence)
#   ✓ Kept review (classified as truthful with  92.57% confidence)
#   ✓ Kept review (classified as truthful with  92.83% confidence)
#   ✓ Kept review (classified as truthful with  91.22% confidence)
#   ✓ Kept review (classified as truthful with  53.32% confidence)
#   Kept 20/20 reviews
#
# Processing hotel #25: Occidental Marco Polo
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  92.14% confidence)
#   ✓ Kept review (classified as truthful with  86.30% confidence)
#   ✓ Kept review (classified as truthful with  86.75% confidence)
#   ✓ Kept review (classified as truthful with  92.72% confidence)
#   ✓ Kept review (classified as truthful with  62.83% confidence)
#   ✓ Kept review (classified as truthful with  65.47% confidence)
#   ✓ Kept review (classified as truthful with  58.06% confidence)
#   ✓ Kept review (classified as truthful with  80.17% confidence)
#   ✓ Kept review (classified as truthful with  72.85% confidence)
#   ✓ Kept review (classified as truthful with  87.07% confidence)
#   ✓ Kept review (classified as truthful with  91.95% confidence)
#   ✓ Kept review (classified as truthful with  91.34% confidence)
#   ✓ Kept review (classified as truthful with  92.29% confidence)
#   ✗ Filtered out (classified as deceptive with 55.71% confidence)
#   ✓ Kept review (classified as truthful with  89.03% confidence)
#   ✓ Kept review (classified as truthful with  93.34% confidence)
#   ✗ Filtered out (classified as deceptive with 88.30% confidence)
#   ✓ Kept review (classified as truthful with  91.57% confidence)
#   ✓ Kept review (classified as truthful with  91.87% confidence)
#   ✓ Kept review (classified as truthful with  91.22% confidence)
#   Kept 18/20 reviews
#
# Processing hotel #26: Djerba Plaza Thalasso & Spa
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  92.42% confidence)
#   ✓ Kept review (classified as truthful with  89.80% confidence)
#   ✓ Kept review (classified as truthful with  73.07% confidence)
#   ✗ Filtered out (classified as deceptive with 87.84% confidence)
#   ✓ Kept review (classified as truthful with  91.77% confidence)
#   ✗ Filtered out (classified as deceptive with 90.20% confidence)
#   ✓ Kept review (classified as truthful with  90.80% confidence)
#   ✓ Kept review (classified as truthful with  90.37% confidence)
#   ✗ Filtered out (classified as deceptive with 65.01% confidence)
#   ✓ Kept review (classified as truthful with  86.35% confidence)
#   ✓ Kept review (classified as truthful with  74.46% confidence)
#   ✓ Kept review (classified as truthful with  92.47% confidence)
#   ✓ Kept review (classified as truthful with  73.18% confidence)
#   ✓ Kept review (classified as truthful with  88.65% confidence)
#   ✓ Kept review (classified as truthful with  87.12% confidence)
#   ✓ Kept review (classified as truthful with  89.40% confidence)
#   ✗ Filtered out (classified as deceptive with 51.75% confidence)
#   ✓ Kept review (classified as truthful with  90.95% confidence)
#   ✓ Kept review (classified as truthful with  78.01% confidence)
#   ✓ Kept review (classified as truthful with  90.39% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #27: Medina Solaria & Thalasso
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  88.94% confidence)
#   ✓ Kept review (classified as truthful with  86.21% confidence)
#   ✓ Kept review (classified as truthful with  89.59% confidence)
#   ✓ Kept review (classified as truthful with  84.38% confidence)
#   ✓ Kept review (classified as truthful with  84.71% confidence)
#   ✓ Kept review (classified as truthful with  72.92% confidence)
#   ✓ Kept review (classified as truthful with  58.98% confidence)
#   ✓ Kept review (classified as truthful with  78.29% confidence)
#   ✓ Kept review (classified as truthful with  89.65% confidence)
#   ✓ Kept review (classified as truthful with  92.00% confidence)
#   ✓ Kept review (classified as truthful with  82.97% confidence)
#   ✓ Kept review (classified as truthful with  91.31% confidence)
#   ✓ Kept review (classified as truthful with  91.62% confidence)
#   ✓ Kept review (classified as truthful with  91.36% confidence)
#   ✓ Kept review (classified as truthful with  54.00% confidence)
#   ✓ Kept review (classified as truthful with  92.46% confidence)
#   ✓ Kept review (classified as truthful with  90.74% confidence)
#   ✓ Kept review (classified as truthful with  91.33% confidence)
#   ✓ Kept review (classified as truthful with  89.65% confidence)
#   ✓ Kept review (classified as truthful with  76.43% confidence)
#   Kept 20/20 reviews
#
# Processing hotel #28: Hotel Menara
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  82.00% confidence)
#   ✓ Kept review (classified as truthful with  92.40% confidence)
#   ✓ Kept review (classified as truthful with  87.85% confidence)
#   ✓ Kept review (classified as truthful with  58.20% confidence)
#   ✓ Kept review (classified as truthful with  92.85% confidence)
#   ✓ Kept review (classified as truthful with  86.45% confidence)
#   ✓ Kept review (classified as truthful with  80.44% confidence)
#   ✓ Kept review (classified as truthful with  92.81% confidence)
#   ✓ Kept review (classified as truthful with  85.54% confidence)
#   ✓ Kept review (classified as truthful with  92.90% confidence)
#   ✗ Filtered out (classified as deceptive with 54.06% confidence)
#   ✓ Kept review (classified as truthful with  91.29% confidence)
#   ✓ Kept review (classified as truthful with  55.88% confidence)
#   ✓ Kept review (classified as truthful with  86.40% confidence)
#   ✗ Filtered out (classified as deceptive with 72.51% confidence)
#   ✗ Filtered out (classified as deceptive with 61.85% confidence)
#   ✓ Kept review (classified as truthful with  79.76% confidence)
#   ✓ Kept review (classified as truthful with  80.54% confidence)
#   ✓ Kept review (classified as truthful with  88.92% confidence)
#   ! Error processing review: The size of tensor a (1781) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   Kept 16/20 reviews
#
# Processing hotel #29: Iberostar Selection Kuriat Palace
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  93.39% confidence)
#   ✗ Filtered out (classified as deceptive with 90.17% confidence)
#   ! Error processing review: The size of tensor a (527) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  81.54% confidence)
#   ✓ Kept review (classified as truthful with  93.52% confidence)
#   ✓ Kept review (classified as truthful with  71.06% confidence)
#   ✗ Filtered out (classified as deceptive with 50.88% confidence)
#   ✓ Kept review (classified as truthful with  88.47% confidence)
#   ✓ Kept review (classified as truthful with  69.95% confidence)
#   ! Error processing review: The size of tensor a (516) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  91.01% confidence)
#   ✗ Filtered out (classified as deceptive with 59.59% confidence)
#   ✓ Kept review (classified as truthful with  84.52% confidence)
#   ✓ Kept review (classified as truthful with  91.78% confidence)
#   ✓ Kept review (classified as truthful with  90.64% confidence)
#   ✓ Kept review (classified as truthful with  93.40% confidence)
#   ✗ Filtered out (classified as deceptive with 62.42% confidence)
#   ✓ Kept review (classified as truthful with  91.19% confidence)
#   ✗ Filtered out (classified as deceptive with 73.50% confidence)
#   ✓ Kept review (classified as truthful with  79.52% confidence)
#   Kept 13/20 reviews
#
# Processing hotel #30: Occidental Sousse Marhaba
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  92.84% confidence)
#   ✗ Filtered out (classified as deceptive with 88.91% confidence)
#   ! Error processing review: The size of tensor a (544) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  84.42% confidence)
#   ✓ Kept review (classified as truthful with  91.47% confidence)
#   ✓ Kept review (classified as truthful with  84.21% confidence)
#   ✓ Kept review (classified as truthful with  92.67% confidence)
#   ✗ Filtered out (classified as deceptive with 88.36% confidence)
#   ✓ Kept review (classified as truthful with  78.99% confidence)
#   ✓ Kept review (classified as truthful with  74.94% confidence)
#   ✓ Kept review (classified as truthful with  92.89% confidence)
#   ✗ Filtered out (classified as deceptive with 87.58% confidence)
#   ✓ Kept review (classified as truthful with  92.01% confidence)
#   ✓ Kept review (classified as truthful with  87.02% confidence)
#   ✓ Kept review (classified as truthful with  91.88% confidence)
#   ✓ Kept review (classified as truthful with  86.23% confidence)
#   ✓ Kept review (classified as truthful with  80.88% confidence)
#   ✓ Kept review (classified as truthful with  92.45% confidence)
#   ✓ Kept review (classified as truthful with  83.82% confidence)
#   ✓ Kept review (classified as truthful with  88.98% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #31: Mahdia Palace
#   Found 20 reviews
#   ✗ Filtered out (classified as deceptive with 80.67% confidence)
#   ✗ Filtered out (classified as deceptive with 83.80% confidence)
#   ✓ Kept review (classified as truthful with  78.74% confidence)
#   ✗ Filtered out (classified as deceptive with 67.16% confidence)
#   ✗ Filtered out (classified as deceptive with 51.69% confidence)
#   ✓ Kept review (classified as truthful with  91.93% confidence)
#   ✓ Kept review (classified as truthful with  90.44% confidence)
#   ✓ Kept review (classified as truthful with  91.73% confidence)
#   ! Error processing review: The size of tensor a (628) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  91.67% confidence)
#   ✓ Kept review (classified as truthful with  89.49% confidence)
#   ✓ Kept review (classified as truthful with  90.05% confidence)
#   ✓ Kept review (classified as truthful with  81.55% confidence)
#   ✓ Kept review (classified as truthful with  91.51% confidence)
#   ✓ Kept review (classified as truthful with  89.11% confidence)
#   ✓ Kept review (classified as truthful with  82.30% confidence)
#   ✓ Kept review (classified as truthful with  92.09% confidence)
#   ✓ Kept review (classified as truthful with  92.21% confidence)
#   ✓ Kept review (classified as truthful with  90.47% confidence)
#   ✓ Kept review (classified as truthful with  90.32% confidence)
#   Kept 15/20 reviews
#
# Processing hotel #32: Mahdia Beach & Aquapark
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  92.43% confidence)
#   ✓ Kept review (classified as truthful with  93.08% confidence)
#   ✓ Kept review (classified as truthful with  86.18% confidence)
#   ✗ Filtered out (classified as deceptive with 57.11% confidence)
#   ✓ Kept review (classified as truthful with  71.14% confidence)
#   ✓ Kept review (classified as truthful with  89.36% confidence)
#   ✓ Kept review (classified as truthful with  91.99% confidence)
#   ✓ Kept review (classified as truthful with  91.35% confidence)
#   ✓ Kept review (classified as truthful with  67.75% confidence)
#   ✓ Kept review (classified as truthful with  87.15% confidence)
#   ✗ Filtered out (classified as deceptive with 63.82% confidence)
#   ✓ Kept review (classified as truthful with  92.67% confidence)
#   ✓ Kept review (classified as truthful with  89.92% confidence)
#   ! Error processing review: The size of tensor a (665) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  91.73% confidence)
#   ✓ Kept review (classified as truthful with  88.37% confidence)
#   ✓ Kept review (classified as truthful with  87.27% confidence)
#   ✗ Filtered out (classified as deceptive with 61.26% confidence)
#   ✓ Kept review (classified as truthful with  84.18% confidence)
#   ✓ Kept review (classified as truthful with  68.70% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #33: Nozha Beach Resort & Spa
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  92.76% confidence)
#   ✓ Kept review (classified as truthful with  92.36% confidence)
#   ✗ Filtered out (classified as deceptive with 60.51% confidence)
#   ✓ Kept review (classified as truthful with  89.04% confidence)
# ...
#   ✓ Kept review (classified as truthful with  78.87% confidence)
#   ✗ Filtered out (classified as deceptive with 82.97% confidence)
#   ✓ Kept review (classified as truthful with  84.82% confidence)
#   ✓ Kept review (classified as truthful with  89.28% confidence)
#   ✓ Kept review (classified as truthful with  90.87% confidence)
#   ✓ Kept review (classified as truthful with  90.65% confidence)
#   ✗ Filtered out (classified as deceptive with 74.89% confidence)
#   ✓ Kept review (classified as truthful with  91.89% confidence)
#   ✓ Kept review (classified as truthful with  85.07% confidence)
#   ✗ Filtered out (classified as deceptive with 76.53% confidence)
#   ✓ Kept review (classified as truthful with  91.45% confidence)
#   ✗ Filtered out (classified as deceptive with 53.50% confidence)
#   ✓ Kept review (classified as truthful with  90.77% confidence)
#   ✓ Kept review (classified as truthful with  88.81% confidence)
#   ✓ Kept review (classified as truthful with  93.62% confidence)
#   ✓ Kept review (classified as truthful with  93.69% confidence)
#   ✓ Kept review (classified as truthful with  87.36% confidence)
#   Kept 15/20 reviews
#
# Processing hotel #161: Rosa Beach Thalasso and Spa
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  85.08% confidence)
#   ✗ Filtered out (classified as deceptive with 90.49% confidence)
#   ✓ Kept review (classified as truthful with  91.77% confidence)
#   ✗ Filtered out (classified as deceptive with 79.17% confidence)
#   ✓ Kept review (classified as truthful with  75.53% confidence)
#   ✓ Kept review (classified as truthful with  91.67% confidence)
#   ✓ Kept review (classified as truthful with  83.80% confidence)
#   ✓ Kept review (classified as truthful with  86.89% confidence)
#   ✓ Kept review (classified as truthful with  82.81% confidence)
#   ✓ Kept review (classified as truthful with  88.35% confidence)
#   ✓ Kept review (classified as truthful with  85.08% confidence)
#   ✓ Kept review (classified as truthful with  91.13% confidence)
#   ✓ Kept review (classified as truthful with  90.31% confidence)
#   ✓ Kept review (classified as truthful with  87.30% confidence)
#   ✓ Kept review (classified as truthful with  88.49% confidence)
#   ✓ Kept review (classified as truthful with  87.37% confidence)
#   ✓ Kept review (classified as truthful with  67.13% confidence)
#   ✓ Kept review (classified as truthful with  90.62% confidence)
#   ✓ Kept review (classified as truthful with  91.68% confidence)
#   ✓ Kept review (classified as truthful with  90.36% confidence)
#   Kept 18/20 reviews
#
# Processing hotel #162: Zephir Hotel & Spa
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  89.71% confidence)
#   ✓ Kept review (classified as truthful with  90.55% confidence)
#   ✓ Kept review (classified as truthful with  88.91% confidence)
#   ✓ Kept review (classified as truthful with  81.99% confidence)
#   ✓ Kept review (classified as truthful with  77.70% confidence)
#   ✓ Kept review (classified as truthful with  85.63% confidence)
#   ✓ Kept review (classified as truthful with  87.69% confidence)
#   ✓ Kept review (classified as truthful with  92.52% confidence)
#   ✓ Kept review (classified as truthful with  91.97% confidence)
#   ✓ Kept review (classified as truthful with  92.07% confidence)
#   ✓ Kept review (classified as truthful with  54.60% confidence)
#   ✓ Kept review (classified as truthful with  89.88% confidence)
#   ✓ Kept review (classified as truthful with  91.92% confidence)
#   ✓ Kept review (classified as truthful with  57.79% confidence)
#   ✓ Kept review (classified as truthful with  91.29% confidence)
#   ✓ Kept review (classified as truthful with  92.62% confidence)
#   ✓ Kept review (classified as truthful with  88.49% confidence)
#   ✓ Kept review (classified as truthful with  85.72% confidence)
#   ✓ Kept review (classified as truthful with  90.88% confidence)
#   ✓ Kept review (classified as truthful with  88.84% confidence)
#   Kept 20/20 reviews
#
# Processing hotel #163: Royal Nozha Hotel
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  90.92% confidence)
#   ✓ Kept review (classified as truthful with  86.00% confidence)
#   ✓ Kept review (classified as truthful with  89.28% confidence)
#   ✓ Kept review (classified as truthful with  90.80% confidence)
#   ✓ Kept review (classified as truthful with  83.42% confidence)
#   ✓ Kept review (classified as truthful with  79.68% confidence)
#   ! Error processing review: The size of tensor a (527) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  93.00% confidence)
#   ✓ Kept review (classified as truthful with  85.24% confidence)
#   ✗ Filtered out (classified as deceptive with 55.66% confidence)
#   ✓ Kept review (classified as truthful with  79.22% confidence)
#   ✓ Kept review (classified as truthful with  88.92% confidence)
#   ✓ Kept review (classified as truthful with  90.37% confidence)
#   ✓ Kept review (classified as truthful with  91.67% confidence)
#   ✓ Kept review (classified as truthful with  75.21% confidence)
#   ✓ Kept review (classified as truthful with  91.22% confidence)
#   ✓ Kept review (classified as truthful with  87.93% confidence)
#   ✓ Kept review (classified as truthful with  93.87% confidence)
#   ✓ Kept review (classified as truthful with  84.06% confidence)
#   ✓ Kept review (classified as truthful with  86.42% confidence)
#   Kept 18/20 reviews
#
# Processing hotel #164: Robinson Djerba Bahiya
#   Found 20 reviews
#   ! Error processing review: The size of tensor a (712) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  92.52% confidence)
#   ✓ Kept review (classified as truthful with  81.53% confidence)
#   ✓ Kept review (classified as truthful with  90.75% confidence)
#   ✓ Kept review (classified as truthful with  78.11% confidence)
#   ! Error processing review: The size of tensor a (1571) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 56.45% confidence)
#   ✓ Kept review (classified as truthful with  93.41% confidence)
#   ✓ Kept review (classified as truthful with  89.66% confidence)
#   ✓ Kept review (classified as truthful with  93.28% confidence)
#   ✓ Kept review (classified as truthful with  90.76% confidence)
#   ✓ Kept review (classified as truthful with  89.92% confidence)
#   ✓ Kept review (classified as truthful with  92.79% confidence)
#   ✗ Filtered out (classified as deceptive with 82.97% confidence)
#   ✗ Filtered out (classified as deceptive with 63.58% confidence)
#   ✓ Kept review (classified as truthful with  92.27% confidence)
#   ✓ Kept review (classified as truthful with  90.08% confidence)
#   ✓ Kept review (classified as truthful with  88.90% confidence)
#   ✓ Kept review (classified as truthful with  91.96% confidence)
#   ✗ Filtered out (classified as deceptive with 79.01% confidence)
#   Kept 14/20 reviews
#
# Processing hotel #166: La Chambre bleue
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  55.33% confidence)
#   ✓ Kept review (classified as truthful with  91.23% confidence)
#   ✗ Filtered out (classified as deceptive with 50.28% confidence)
#   ✓ Kept review (classified as truthful with  91.22% confidence)
#   ✓ Kept review (classified as truthful with  86.01% confidence)
#   ✗ Filtered out (classified as deceptive with 85.39% confidence)
#   ✓ Kept review (classified as truthful with  83.98% confidence)
#   ✓ Kept review (classified as truthful with  88.98% confidence)
#   ✗ Filtered out (classified as deceptive with 74.08% confidence)
#   ✓ Kept review (classified as truthful with  89.01% confidence)
#   ✓ Kept review (classified as truthful with  93.32% confidence)
#   ✗ Filtered out (classified as deceptive with 76.68% confidence)
#   ✓ Kept review (classified as truthful with  94.02% confidence)
#   ✗ Filtered out (classified as deceptive with 88.55% confidence)
#   ! Error processing review: The size of tensor a (571) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ! Error processing review: The size of tensor a (1729) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✗ Filtered out (classified as deceptive with 78.99% confidence)
#   ✓ Kept review (classified as truthful with  83.16% confidence)
#   ✓ Kept review (classified as truthful with  89.58% confidence)
#   ✓ Kept review (classified as truthful with  58.43% confidence)
#   Kept 12/20 reviews
#
# Processing hotel #167: Omar Khayam
#   Found 20 reviews
#   ✗ Filtered out (classified as deceptive with 70.52% confidence)
#   ✓ Kept review (classified as truthful with  92.32% confidence)
#   ✓ Kept review (classified as truthful with  81.96% confidence)
#   ✓ Kept review (classified as truthful with  84.01% confidence)
#   ✓ Kept review (classified as truthful with  64.49% confidence)
#   ✓ Kept review (classified as truthful with  86.34% confidence)
#   ✓ Kept review (classified as truthful with  90.51% confidence)
#   ✓ Kept review (classified as truthful with  91.58% confidence)
#   ✓ Kept review (classified as truthful with  90.23% confidence)
#   ✓ Kept review (classified as truthful with  64.73% confidence)
#   ✓ Kept review (classified as truthful with  93.16% confidence)
#   ✓ Kept review (classified as truthful with  90.04% confidence)
#   ! Error processing review: The size of tensor a (1196) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  91.81% confidence)
#   ✓ Kept review (classified as truthful with  89.73% confidence)
#   ✓ Kept review (classified as truthful with  88.26% confidence)
#   ✓ Kept review (classified as truthful with  91.66% confidence)
#   ✓ Kept review (classified as truthful with  62.04% confidence)
#   ✓ Kept review (classified as truthful with  86.78% confidence)
#   ✗ Filtered out (classified as deceptive with 88.82% confidence)
#   Kept 17/20 reviews
#
# Processing hotel #168: El Borj Hotel
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  68.23% confidence)
#   ✓ Kept review (classified as truthful with  91.40% confidence)
#   ✓ Kept review (classified as truthful with  86.33% confidence)
#   ✓ Kept review (classified as truthful with  91.43% confidence)
#   ✓ Kept review (classified as truthful with  84.42% confidence)
#   ✓ Kept review (classified as truthful with  51.46% confidence)
#   ✓ Kept review (classified as truthful with  91.32% confidence)
#   ✗ Filtered out (classified as deceptive with 80.23% confidence)
#   ✗ Filtered out (classified as deceptive with 84.15% confidence)
#   ✓ Kept review (classified as truthful with  76.22% confidence)
#   ✗ Filtered out (classified as deceptive with 77.23% confidence)
#   ✓ Kept review (classified as truthful with  86.69% confidence)
#   ✓ Kept review (classified as truthful with  80.82% confidence)
#   ✓ Kept review (classified as truthful with  83.95% confidence)
#   ! Error processing review: The size of tensor a (678) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  93.39% confidence)
#   ✗ Filtered out (classified as deceptive with 80.17% confidence)
#   ✓ Kept review (classified as truthful with  92.56% confidence)
#   ✗ Filtered out (classified as deceptive with 88.80% confidence)
#   ✓ Kept review (classified as truthful with  71.03% confidence)
#   Kept 14/20 reviews
#
# Processing hotel #169: TMK L'Atrium Yasmine by Turismark
#   Found 20 reviews
#   ✗ Filtered out (classified as deceptive with 54.65% confidence)
#   ✓ Kept review (classified as truthful with  89.71% confidence)
#   ✓ Kept review (classified as truthful with  86.74% confidence)
#   ✓ Kept review (classified as truthful with  93.40% confidence)
#   ✓ Kept review (classified as truthful with  90.38% confidence)
#   ✓ Kept review (classified as truthful with  90.46% confidence)
#   ✓ Kept review (classified as truthful with  75.81% confidence)
#   ✓ Kept review (classified as truthful with  88.18% confidence)
#   ✓ Kept review (classified as truthful with  91.57% confidence)
#   ! Error processing review: The size of tensor a (985) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  92.26% confidence)
#   ✓ Kept review (classified as truthful with  90.36% confidence)
#   ✓ Kept review (classified as truthful with  86.13% confidence)
#   ✓ Kept review (classified as truthful with  55.60% confidence)
#   ! Error processing review: The size of tensor a (551) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  92.36% confidence)
#   ✓ Kept review (classified as truthful with  70.00% confidence)
#   ✓ Kept review (classified as truthful with  92.21% confidence)
#   ✓ Kept review (classified as truthful with  91.60% confidence)
#   ✗ Filtered out (classified as deceptive with 77.33% confidence)
#   Kept 16/20 reviews
#
# Processing hotel #170: El Mouradi Club Selima
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  85.49% confidence)
#   ✓ Kept review (classified as truthful with  90.02% confidence)
#   ✓ Kept review (classified as truthful with  90.42% confidence)
#   ✓ Kept review (classified as truthful with  89.24% confidence)
#   ✓ Kept review (classified as truthful with  93.75% confidence)
#   ✓ Kept review (classified as truthful with  90.24% confidence)
#   ✓ Kept review (classified as truthful with  92.43% confidence)
#   ✓ Kept review (classified as truthful with  92.99% confidence)
#   ✓ Kept review (classified as truthful with  86.04% confidence)
#   ✗ Filtered out (classified as deceptive with 79.57% confidence)
#   ✗ Filtered out (classified as deceptive with 88.12% confidence)
#   ✓ Kept review (classified as truthful with  86.14% confidence)
#   ✓ Kept review (classified as truthful with  87.54% confidence)
#   ✓ Kept review (classified as truthful with  89.94% confidence)
#   ✓ Kept review (classified as truthful with  84.92% confidence)
#   ✓ Kept review (classified as truthful with  90.91% confidence)
#   ✓ Kept review (classified as truthful with  87.87% confidence)
#   ✓ Kept review (classified as truthful with  92.74% confidence)
#   ✓ Kept review (classified as truthful with  93.03% confidence)
#   ✗ Filtered out (classified as deceptive with 69.39% confidence)
#   Kept 17/20 reviews
#
# Processing hotel #171: Byzance Hotel
#   Found 20 reviews
#   ✓ Kept review (classified as truthful with  91.86% confidence)
#   ✓ Kept review (classified as truthful with  93.31% confidence)
#   ✓ Kept review (classified as truthful with  87.15% confidence)
#   ✓ Kept review (classified as truthful with  86.48% confidence)
#   ✓ Kept review (classified as truthful with  89.36% confidence)
#   ✓ Kept review (classified as truthful with  92.86% confidence)
#   ✓ Kept review (classified as truthful with  81.88% confidence)
#   ✓ Kept review (classified as truthful with  89.05% confidence)
#   ✓ Kept review (classified as truthful with  67.76% confidence)
#   ✓ Kept review (classified as truthful with  92.27% confidence)
#   ✗ Filtered out (classified as deceptive with 80.16% confidence)
#   ✓ Kept review (classified as truthful with  89.40% confidence)
#   ✓ Kept review (classified as truthful with  77.55% confidence)
#   ✓ Kept review (classified as truthful with  89.60% confidence)
#   ✓ Kept review (classified as truthful with  91.22% confidence)
#   ✓ Kept review (classified as truthful with  89.94% confidence)
#   ✓ Kept review (classified as truthful with  91.57% confidence)
#   ✓ Kept review (classified as truthful with  80.54% confidence)
#   ! Error processing review: The size of tensor a (775) must match the size of tensor b (512) at non-singleton dimension 1 - remove it to be safe
#   ✓ Kept review (classified as truthful with  58.99% confidence)
#   Kept 18/20 reviews
#
# SUMMARY:
# Total reviews processed: 3379
# Reviews kept (truthful): 2807 (83.1%)
# Reviews filtered out: 572 (16.9%)
# Results saved to: hotels_details_reviews_filtered.json
